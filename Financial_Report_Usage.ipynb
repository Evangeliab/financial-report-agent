# %% [markdown]
# # Financial Report Workspace Setup
#
# This notebook will guide you through setting up a new workspace for the Financial Report project in Visual Studio Code. Follow each section to configure your environment and run the financial report agent.

# %% [markdown]
# ## 1. Create a New Workspace
#
# Open Visual Studio Code and create a new workspace for your Financial Report project. Save the workspace file in your project directory.

# %% [markdown]
# ## 2. Configure Workspace Settings
#
# Set your Python interpreter, enable linting, and configure formatting options in VS Code. You can do this via the Command Palette or by editing `.vscode/settings.json`.

# %% [markdown]
# ## 3. Install Required Extensions
#
# Install the following recommended extensions for Python development:
# - Python
# - Jupyter
# - GitLens
#
# You can find these in the Extensions view (`Cmd+Shift+X`).

# %% [markdown]
# ## 4. Set Up Source Control Integration
#
# Initialize a Git repository in your project folder and connect it to a remote (e.g., GitHub) for version control. Use the Source Control view in VS Code to manage commits and branches.

# %% [markdown]
# ## 5. Initialize Project Structure
#
# Create folders for your source code, tests, and data. Your project should include:
# - `financial_report_agent_refactor.py` (main agent)
# - `requirements.txt` (dependencies)
# - This notebook for usage demonstration

# %% [markdown]
# ## 6. Install Dependencies
#
# Run the following command in your terminal to install all required packages:
#
# ```bash
# pip install -r requirements.txt
# ```

# %% [markdown]
# ## 7. Run the Financial Report Agent
#
# Use the following code to generate a financial report for a given ticker symbol (e.g., TSLA):

# %%
from financial_report_agent_refactor import run_financial_report, MODEL_NAME, llm
from IPython.display import Markdown, display
import os

# Quick LLM availability check
print('MODEL_NAME =', MODEL_NAME)
print('LLM instantiated:', llm is not None)

# Run the report (this will require an LLM by default)
state = run_financial_report('TSLA')
display(Markdown(state['markdown_report']))
# Out:
# /Users/ebrillaki/Projects/financial_report_agent/financial-report-agent/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/ebrillaki/Projects/financial_report_agent/financial-report-agent/.venv/lib/python3.9/site-packages/google/api_core/_python_version_support.py:252: FutureWarning: You are using a Python version (3.9.6) past its end of life. Google will update google.api_core with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# An error occurred: module 'importlib.metadata' has no attribute 'packages_distributions'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/Projects/financial_report_agent/financial-report-agent/financial_report_agent_refactor.py:121
#     120     llm = ChatGoogleGenerativeAI(model=MODEL_NAME, temperature=0.0, max_retries=2)
# --> 121     logger.info("Instantiated LLM client with model=%s", MODEL_NAME)
#     122 except Exception as e:
#     123     # If instantiation fails (e.g., unsupported model name), disable LLM usage but log the error
#
# NameError: name 'logger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from financial_report_agent_refactor import run_financial_report
#       2 from IPython.display import Markdown, display
#       4 state = run_financial_report('TSLA')
#
# File ~/Projects/financial_report_agent/financial-report-agent/financial_report_agent_refactor.py:124
#     121         logger.info("Instantiated LLM client with model=%s", MODEL_NAME)
#     122     except Exception as e:
#     123         # If instantiation fails (e.g., unsupported model name), disable LLM usage but log the error
# --> 124         logger.warning("Failed to instantiate LLM client for model=%s: %s", MODEL_NAME, repr(e))
#     125         llm = None
#     127 # Logger for warnings/errors
#
# NameError: name 'logger' is not defined

# %%
state = run_financial_report('GOOGL')
display(Markdown(state['markdown_report']))
# Out:
# # GOOGL Investment Commentary - November 06, 2025
#
#
# ## 📈 Price Chart
#
# ![Stock Price Chart](data:image/png;base64,...)
#
#
# ## 📊 Key Financial Metrics
#
# - **P/E (trailing)**: 28.06614
#
# - **PEG**: 0.85
#
# - **Revenue Growth (%)**: 15.90%
#
# - **Debt/Equity**: 11.42
#
# - **Market Cap (USD)**: $3,432,936,112,128
#
#
# **Analyst Recommendation:** **Buy**
#
#
# ## 📰 News Sentiment Summary
#
# - Positive: 0  |  Neutral: 0  |  Negative: 0
#
#
# ## 🧠 Analyst Commentary
#
# GOOGL: Strong Growth and Reasonable Valuation Support Continued Outperformance
#
# Alphabet (GOOGL) continues to demonstrate robust financial health and growth, positioning it favorably for sustained performance. The company reported a healthy 15.90% revenue growth, underpinned by its diversified business segments. With a trailing P/E ratio of 28.07x and a compelling PEG ratio of 0.85, GOOGL appears reasonably valued given its earnings growth trajectory. Furthermore, its balance sheet remains exceptionally strong, evidenced by a low Debt/Equity ratio of 11.42%, providing significant financial flexibility. The company's substantial market capitalization of over $3.4 trillion underscores its dominant position in the global technology landscape.
#
# Recent news flow for Alphabet has been mixed but generally supportive of its long-term strategic initiatives. Positive sentiment has largely stemmed from continued innovation in Artificial Intelligence, particularly with reports detailing the enhanced capabilities and broader integration of its Gemini AI models across its product ecosystem, including Search and Google Cloud Platform. This is expected to bolster its competitive edge and drive future revenue streams. Conversely, the company continues to navigate a complex regulatory landscape, with ongoing antitrust scrutiny in key markets regarding its advertising practices and app store policies. While no definitive adverse rulings have emerged, the persistent regulatory pressure remains a watch item.
#
# **Risks:**
# 1.  **Regulatory Scrutiny:** Ongoing antitrust investigations and potential legislative actions globally could lead to significant fines, operational restrictions, or mandated business changes, impacting profitability and market structure.
# 2.  **Intense Competition:** Alphabet faces fierce competition across its core segments, including AI (from OpenAI, Microsoft), cloud computing (AWS, Azure), and digital advertising (Meta, Amazon, TikTok), which could pressure margins and market share.
# 3.  **Advertising Market Volatility:** A significant portion of Alphabet's revenue is derived from advertising. Economic downturns or shifts in advertiser spending patterns could directly impact its top-line growth and profitability.
#
# **Next Steps:**
# Investors should closely monitor Alphabet's upcoming Q4 2025 earnings report and management's guidance for 2026, particularly regarding AI monetization strategies and Google Cloud's profitability trajectory. Further developments in global regulatory investigations and any shifts in the broader digital advertising market will also be crucial to assess the company's operational environment and potential headwinds.
#
#
# ## ⚠️ Risks
#
# - Macroeconomic weakness that impacts revenue growth
# - Company-specific execution issues
# - Regulatory or legal risks
#
#
# ## ▶️ Next Steps
#
# - Monitor upcoming earnings and management commentary
# - Watch sector ETF and macro indicators (rates, unemployment)
# - Re-run sentiment after major news events
