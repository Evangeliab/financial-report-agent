# %% [markdown]
# # Financial Report Agent Usage
# This notebook demonstrates how to generate automated financial reports for any stock ticker using the Financial Report Agent.

# %%
from financial_report_agent_refactor import run_financial_report
from IPython.display import Markdown, display

# Generate a financial report for TSLA using StateGraph orchestration
state = run_financial_report("TSLA", use_graph=True)
display(Markdown(state["markdown_report"]))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762798355.255390 6392912 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# INFO:financial_report_agent_refactor:Instantiated LLM client with model=gemini-2.5-flash
# ERROR:yfinance:Failed to get ticker 'TSLA' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:Failed to get ticker 'TSLA' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:TSLA: No price data found, symbol may be delisted (period=1y)
# ERROR:yfinance:TSLA: No price data found, symbol may be delisted (period=1y)
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TSLA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TSLA&crumb=Edge%3A+Too+Many+Requests
# ...

# %%
from financial_report_agent_refactor import run_financial_report
from IPython.display import Markdown, display

# Generate a financial report for MSFT using StateGraph orchestration
state = run_financial_report("MSFT", use_graph=True)
display(Markdown(state["markdown_report"]))
# Out:
# ERROR:yfinance:Failed to get ticker 'MSFT' reason: Expecting value: line 1 column 1 (char 0)
# ERROR:yfinance:MSFT: No price data found, symbol may be delisted (period=1y)
# ERROR:yfinance:MSFT: No price data found, symbol may be delisted (period=1y)
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSFT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSFT&crumb=Edge%3A+Too+Many+Requests
# ERROR:yfinance:429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSFT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSFT&crumb=Edge%3A+Too+Many+Requests
# ...

# %%
# Diagnostic 1: quick environment + LLM checks
import os
from financial_report_agent_refactor import get_model_name, MODEL_NAME, llm

print("Python process sees GOOGLE_MODEL:", os.environ.get("GOOGLE_MODEL"))
print("get_model_name() ->", get_model_name())
print("MODEL_NAME (import-time) ->", MODEL_NAME)
print("GOOGLE_API_KEY present in env:", bool(os.environ.get("GOOGLE_API_KEY")))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Diagnostic 1: quick environment + LLM checks
#       2 import os
# ----> 3 from financial_report_agent_refactor import get_model_name, MODEL_NAME, llm
#       5 print("Python process sees GOOGLE_MODEL:", os.environ.get("GOOGLE_MODEL"))
#       6 print("get_model_name() ->", get_model_name())
#
# ImportError: cannot import name 'MODEL_NAME' from 'financial_report_agent_refactor' (/Users/bf40fo/PycharmProjects/financial_report/financial_report_agent_refactor.py)
